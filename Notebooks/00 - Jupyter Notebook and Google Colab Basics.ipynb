# %% [markdown]
# # PHYS 308 - Notebook 00 - Jupyter Notebook and Google Colab Basics
#
# Interactive learning notebook developed by J. Dolen at Purdue University Northwest
#
# ## Introduction
#
#
# ### What is python?
#
# Python is a programming language which is very commonly used in physics, engineering, and in industry. It is an interpreted high-level language which focusses on code readability. There are thousands of external python packages which extend python's capabilities and make it very useful for calculations and plotting (among other things).
#
# Documentation: https://docs.python.org/3.10/index.html
#
# Example scientific package: https://numpy.org/
#
# ### What is a Jupyter Notebook?
#
# A Jupyter Notebook is a web application (it opens in your browser) which allows you to write, save, and share interactive documents which contain text, live code (you can actually run the code within the browser), plots, images, and equations. Jupyter supports three default code languages (Julia, Python, and R) which is where its name comes from. You may also see these notebooks refered to as ipython notebooks but this is a somewhat depricated term. We will focus on python in this course.
#
# More info: https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html
#
# ### What is Google Colab?
#
# Google Colab is a hosted Jupyter notebook service that allows you to open and run Jupyter Notebooks without installing any software.
#
# Intro: https://colab.research.google.com/notebooks/intro.ipynb
#
# Tutorial: https://colab.research.google.com/notebooks/basic_features_overview.ipynb
#
#
# ### What is Binder?
#
# Binder is another hosted Jupyter service which allows you to run Jupyter notebooks without installing any software.
#
# https://mybinder.org/

# %% [markdown]
# ## Quickstart: Run this notebook on your own
#
# Please find below instructions on running and interacting with this notebook yourself. If you wish to simply listen you can skip this section.

# %% [markdown]
# 1.   Navigate to [https://github.com/jdolen](https://github.com/jdolen)
# 2.   Click on "PurdueNorthwest_PHYS308_ScientificComputing1"
# 3.   Click on "Notebooks". Copy this link "[https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/tree/master/Notebooks](https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/tree/master/Notebooks)"
# 4. Seperately navigate to [https://colab.research.google.com](https://colab.research.google.com)
# 5.   Click on "File"->"Open notebook"
# 6.   Click on "GitHub" on the top bar
# 7.   In the search bar paste the GitHub link from above
# 8.   Click on the notebook you wish to open.

# %% [markdown]
# ## A few examples of what you can do with a Jupyter notebook

# %% [markdown]
# <font color=magenta>**Display nicely formatted text: (double click on the cell below to edit the text)**</font>

# %% [markdown]
# Jupyter is cool because:
#
# - you can make lists
# - you can run code
# - you can make nice plots

# %% [markdown]
# <font color=magenta>**Display nicely formatted equations using LaTeX** </font>

# %% [markdown]
# Example 1:  $~~E=\gamma m c^2$

# %% [markdown]
# Example 2:  $~~i \hbar \frac{\partial}{\partial t} \Psi(x,t) = \big[-\frac{\hbar^2}{2m}\frac{\partial^2}{\partial x^2} + V(x,t)\big]\Psi(x,t)$

# %% [markdown]
# <font color=magenta>**Write and run code**. Note: You can run the code by clicking on the cell below and typing "shift-enter" ("control-enter" and "command-enter" also work). In Google Colab you can also run the code by pressing play on the left side of the cell. You can edit the code by double clicking on it. Try iterating from 0 to 20 instead.

# %%
stop = 12
for n in range(stop):
    print("Loop iteration",n)
# Out:
# Loop iteration 0
# Loop iteration 1
# Loop iteration 2
# Loop iteration 3
# Loop iteration 4
# Loop iteration 5
# Loop iteration 6
# Loop iteration 7
# Loop iteration 8
# Loop iteration 9
# Loop iteration 10
# Loop iteration 11

# %% [markdown]
# <font color=magenta>**Make and display professional-looking plots and graphs**</font>

# %%
# Example plotting script using python 
#   as well as the numpy and matplotlib external packages 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

# Define some functions
x = np.linspace(-1,4,101)
y1 = np.exp(-x)
y2 = -np.exp(-x)
y3 = np.cos(2 * np.pi * x) * np.exp(-x)

plt.plot(x,y1,"g--" , label='Damping rate')
plt.plot(x,y2,"g--" , label='')
plt.plot(x,y3,"b-." , label='Damped oscillation') # Use LaTeX 

# Set the range of the x and y axis
plt.xlim(0,4)
plt.ylim(-1.1,1.1)

# Label the axes and increase the font
plt.xlabel("time (s)"      , fontsize=20)
plt.ylabel("Position (cm)"      , fontsize=20)

# Title the plot
plt.title('Under-damped Oscillation', fontsize=20)

# Draw a legend
#   loc -> location. examples: 'upper right', 'upper center', 'best'
#   fontsize. examples large etc.
#   framealpha -> set transparency
plt.legend(loc='upper right', fontsize='large', framealpha=1)

# Draw a grid
plt.grid(True)

# Increase axis tick labels (there are a few ways to do this)
plt.tick_params(axis='both', which='major', labelsize=20)

# Display the plot on screen 
plt.show()

# %% [markdown]
# <font color=magenta>**Analyze Data**</font>

# %%
# Example using the external python package pandas 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Make a pandas Dataframe
df = pd.DataFrame(
    [   #[Population, county, area (square miles)]
        [77879,  "Lake",23.81],
        [69093,  "Lake",50.6],
        [34151,"Porter",16.43],
        [14375,"Porter",9.49],
        [37926,"Porter",27.65],
        [33899,  "Lake",17.98],
        [36524,  "Lake",33.29],
        [23761,  "Lake",7.73]
    ],
    index = ["Hammond", "Gary", "Valparaiso", "Chesterton", "Portage", "Crown Point", "Merrillville", "Munster"],
    columns = ["Population","County","Area"]
)

# Display the DataFrame
display(df)
# Out:
#               Population  County   Area
# Hammond            77879    Lake  23.81
# Gary               69093    Lake  50.60
# Valparaiso         34151  Porter  16.43
# Chesterton         14375  Porter   9.49
# Portage            37926  Porter  27.65
# Crown Point        33899    Lake  17.98
# Merrillville       36524    Lake  33.29
# Munster            23761    Lake   7.73

# %%
# Select only cities that satisfy some criteria
df_filtered = df.loc[(df['Population'] > 30000 ) & (df['Area'] <30) ]
df_filtered
# Out:
#              Population  County   Area
# Hammond           77879    Lake  23.81
# Valparaiso        34151  Porter  16.43
# Portage           37926  Porter  27.65
# Crown Point       33899    Lake  17.98

# %%
# Plot the square of cities which satisfy some criteria
df_filtered.plot.bar(y='Area')
plt.title('Square area of cities with population greater than 30,000 and area less than 30 mi$^2$', fontsize=13)
plt.ylabel("Area (square miles)"      , fontsize=13)
plt.show()

# %% [markdown]
# <font color=magenta>**Display images**</font>

# %% [markdown]
# ![Image of Yaktocat](https://raw.githubusercontent.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/master/Images/LeoTheLion2.jpg)

# %% [markdown]
# <font color=magenta>**Display and solve equations**</font>

# %%
# Example using the external python package sympy (symbolic computing)

import sympy as sy
sy.init_printing() # display better looking symbols in Jupyter notebooks
a,b,c,x= sy.symbols("a,b,c,x") 
f = a*x**2 + b*x + c
sy.solve(f,x)
# Out:
# ⎡        _____________          _____________⎤
# ⎢       ╱           2          ╱           2 ⎥
# ⎢-b - ╲╱  -4⋅a⋅c + b    -b + ╲╱  -4⋅a⋅c + b  ⎥
# ⎢─────────────────────, ─────────────────────⎥
# ⎣         2⋅a                    2⋅a         ⎦

# %% [markdown]
# ## How to use Jupyter Notebooks
#
# ### Using Google Colab
#
# With Google Colab you don't have to install anything. Simply navigate to:
#
# https://colab.research.google.com
#
# To open a notebook, click on "File"->"Open Notebook". You can open a noteboook saved on your computer, or open a notebook saved online. For this class I have posted the notebooks on github. Within google colab click on Github and pasted the link below:
#
# https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/tree/master/Notebooks
#
# Then click on the notebook you wish to open:
#
# ![Github](https://raw.githubusercontent.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/master/Images/github_google_colab.png)
#
#
# ### How to install Jupyter on your home computer

# %% [markdown]
# The easiest way to install Jupyter along with python and other useful packages is to install software known as "Anaconda":
#
# https://www.anaconda.com/distribution/
#
# You can find more information here:
#
# https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/install.html

# %% [markdown]
# ### How to open Jupyter Notebooks on your computer
#
# The easiest way to do this (without installing anything) is to open the notebook using Google Colab.
#
# If you are on a computer which has Jupyter installed you can open a Jupyter noteboook as follows:
#
# Anaconda Navigator Method:
#
# Open the installed Anaconda-Navigator program on your computer. Click on Jupyter Notebook.
#
#
# Terminal Method:
#
# On a Mac:
# - open the terminal application (in Applications->Utilities)
# - type "jupyter notebook" and press enter
#
# On a Windows machine:
#
# - Find jupyter notebook in the start menu
# - You can also open a terminal and type "jupyter notebook"
#
# You can find more information here:
#
# https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/execute.html

# %% [markdown]
# ### How to run of the class Jupyter notebooks without installing anything
#
# As we progress through the class I will post notebooks in Github. You can open these notebooks with Google Colab, or you can open them with Jupyter if it is installed on your computer, or you can open them through a service called Binder. The github link is below:
#
# https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1
#
# In google Colab, you can simply navigate to a given notebook in github and then copy and paste the url into Colab.
#
# To open with Binder you can either click on the button in github or below to open the notebooks:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/master)
#
# We may use some packages later in the class that do not work in Binder. For these packages you may have to install Anaconda and Jupyter.

# %% [markdown]
# ### How to use Jupyter Notebooks

# %% [markdown]
# <br>
# <font color=blue>**Navigate your new notebook and create and run cells**</font>
#
# The Jupyter Notebook is organized into individual "cells". Initiall you have just one cell but you can create more by clicking on the "+" button on the toolbar.
#
# There are two principal types of cells:
# 1. Code cells
# 2. Markdown cells
#
# You can switch between these using the dropdown menu on the toolbar.
#
# Code cells expect python code and they will interpret and run what you type after your press "shift enter"
#
# Markdown cells are where you can write nicely formatted text (like in this current cell) and display it by pressing "shift enter". To learn how to edit text using markdown language you can click on "Help" then "Markdown".

# %% [markdown]
# <font color=blue>**Create a new notebook**</font>
#
# Click on the "File" menu on the toolbar and select "New Notebook" then select "Python 3"
# <br>
# <br>
# <font color=blue>**Save a notebook so that you can open it later**</font>
#
# *Local save*: Click on the "File" menu on the toolbar and select "Save and Checkpoint"
# <br>
# <br>
# <font color=red> Caution! On PNW computers the local save file will disappear once you logout of the computer</font>
#
# *Permanent save*: Click on the "File" menu on the toolbar and select "Download As" then select "Notebook (.ipynb file). Save the file to your H drive so that you can access it from anywhere. Recomendation: Also email the notebook to yourself so you are sure not to lose it.
# <br>
# <br>
# <font color=purple> Note: Jupyter notebook files are known as "ipynb" files which stands for "ipython notebook" </font>

# %% [markdown]
# Jupyter notebooks also allow you to navigate and create new cells using your keyboard and not your mouse. Hello.
#
# When a cell is highlighted in <font color=green>green</font>  you are in "Edit Mode" and you can type and write code within the cell. To enter Edit Mode you just have to click on a cell with your mouse or move to it using your arrow keys and press "Enter"
#
# When a cell is highlighted in <font color=blue>blue</font> you are in "Command Mode" and the keyboard can now be used to run shortcuts to create new cells, change the mode of a cell, delete cells, or move between cells. To enter Command Mode you can press "esc" on a currently highlighted green cell or by clicking outside of a cell with your mouse.
#
# You can click on the toolbar "Help" then "Keyboard Shortcuts" to find out what commands are available when in Command Mode. My favorites are the following:
#
#  - m - Convert a cell to a markdown cell
#  - y - Convert a cell to a code cell
#  - a - Insert new cell abbove
#  - b - Insert new cell below
#  - x - cut cell
#  - c - copy cell
#  - v - paste cell
#  - Up and down arrow - navigate between cells
#  - esc - Change to command mode
#  - Enter - Change to edit mode
#  - Shift-Enter - Run the cell

# %% [markdown]
# <br>
# <font color=blue>**Writing code in your jupyter notebook**</font>
#
# Cells run in the order in which you run them or you can run them all from top down.
#
# Your code in one cell may depend on code in a different cell (for example if you create a function or import a package in one cell and then run a funciton in a different cell). You must import the packgage or define the function before running the dependent cell.
#
# A quick example:

# %%
print(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 print(pi)
#
# NameError: name 'pi' is not defined

# %%
from math import pi             # import the variable pi

# %%
print(pi)

# %% [markdown]
# If your code is taking too long to run you can click on Kernel->Interupt.
#
# If you are having big problems (lots of errors) you may want to try doing Kernel->Restart.
#
# When you are done working, save your Notebook (as discussed above) and click "File"->"Close and Halt" (otherwise your notebook will keep running in the background even if you close the window.

# %% [markdown]
# <br>
# <font color=blue>**Dealing with error messages**</font>
#
# The Jupyter notebook will display standard python error messages. Generally these messages contain a line number where the interpeter thinks the error is coming from. Therefore I would recommmend turning on line numbers in Jupyter by going to "View"->"Toggle Line Numbers"

# %%
print(oiafdg)
